# %%
from sns import *
import sympy as sym

# %% [markdown]
# ![](e1.png)
# ![](a1.png)

# %%
t = symbol("t")
x = Heaviside(t-2) - sym.exp(-2 * t) * Heaviside(t)
X = fourier(x, t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c0845adc1bfa> in <module>
#       1 t = symbol("t")
#       2 x = Heaviside(t-2) - sym.exp(-2 * t) * Heaviside(t)
# ----> 3 X = fourier(x, t)
#
# ~\Desktop\Jupyter-notebooks\Signals-Systems\ch5, Fourier Transforms\sns.py in fourier(expression, var, useT)
#     234     T = symbol("T", complex=True)
#     235     if not useT:
# --> 236         transform = fourier_transform(expression, var, k)
#     237         transform1 = transform.subs(k, w / (2 * pi_))
#     238     else:
#
# ~\ANACONDA3\lib\site-packages\sympy\integrals\transforms.py in fourier_transform(f, x, k, **hints)
#    1395     mellin_transform, laplace_transform
#    1396     """
# -> 1397     return FourierTransform(f, x, k).doit(**hints)
#    1398
#    1399
#
# ~\ANACONDA3\lib\site-packages\sympy\integrals\transforms.py in doit(self, **hints)
# ...
