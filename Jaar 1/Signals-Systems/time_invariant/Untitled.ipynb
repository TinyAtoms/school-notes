# %%
from scipy import signal
from numpy import *
from sns import *

# %% [markdown]
# ![](1.png)

# %%
t = arange(-1, 10, 0.1)
def x(t):
    return cos(t)

data = array([t, x(t), 5 * x(t+5)])
multiplot(data, ["x(t)", "x(t+5)"])

# %%
data = array([t, x(t),  x(t**2)])
multiplot(data, ["x(t)", "x(t^2)"])
